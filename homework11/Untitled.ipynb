# %%
import pandas as pd

# %%
data = pd.read_csv('Downloads/athlete_events.csv')

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# **1. How old were the youngest male and female participants of the 1996 Olympics?**
#
# 16 and 15
# <p>14 and 12</p>
# <p>16 and 12</p>
# <p>13 and 11</p>

# %%
new_data = data.loc[(data['Year'] == 1996) & (data['Sex'] == 'M')]
new_data.sort_values(by = 'Age')
# Out:
#            ID                  Name Sex   Age  Height  Weight         Team  \
# 87416   44326       Gwon Gyeong-Min   M  14.0   165.0    60.0  South Korea
# 170448  85647                Ng Sui   M  15.0     NaN     NaN    Hong Kong
# 139132  69887  Keng Liat "Alex" Lim   M  15.0   178.0    63.0     Malaysia
# 139133  69887  Keng Liat "Alex" Lim   M  15.0   178.0    63.0     Malaysia
# 80392   40801       Daniel A. Glomb   M  15.0   178.0    80.0       Brazil
# ...       ...                   ...  ..   ...     ...     ...          ...
# 119298  60395        Boureima Kimba   M   NaN     NaN     NaN        Niger
# 148866  74668           Abdou Manzo   M   NaN     NaN     NaN        Niger
# 181426  91182  Raymond Anthony Papa   M   NaN     NaN     NaN  Philippines
# 181427  91182  Raymond Anthony Papa   M   NaN     NaN     NaN  Philippines
# 181428  91182  Raymond Anthony Papa   M   NaN     NaN     NaN  Philippines
#
#         NOC        Games  Year  Season     City      Sport  \
# ...

# %%
new_data = data.loc[(data['Year'] == 1996) & (data['Sex'] == 'F')]
new_data.sort_values(by = 'Age')
# Out:
#            ID                                        Name Sex   Age  Height  \
# 93850   47506                                Hem Reaksmey   F  12.0   175.0
# 79034   40133                               Cerian Gibbes   F  13.0     NaN
# 78869   40035                                 Mira Ghniem   F  13.0     NaN
# 172477  86657                                   No Ju-Hui   F  13.0   172.0
# 33106   17045                             Byeon Hye-Yeong   F  13.0   166.0
# ...       ...                                         ...  ..   ...     ...
# 66457   33993                       Daria Camilla Fantoni   F  54.0   173.0
# 88528   44891  Ulla Margareta Mileva Hkansson (Svenfelt-)   F  58.0   170.0
# 88527   44891  Ulla Margareta Mileva Hkansson (Svenfelt-)   F  58.0   170.0
# 162717  81706                                     Moosaka   F   NaN     NaN
# 162718  81706                                     Moosaka   F   NaN     NaN
#
# ...

# %% [markdown]
# **Answer: 14 and 12**

# %% [markdown]
# **2. What was the percentage of male gymnasts among all the male participants of the 2000 Olympics? Round the answer to the first decimal.**
#
# Hint: here and further if needed drop duplicated sportsmen to count only unique ones.
#
# 0.2
# <p>1.5</p>
# <p>2.5</p>
# <p>7.7</p>

# %%
data.drop_duplicates(subset = 'ID', inplace = True, keep = 'first')

# %%
new2000 = data.loc[(data['Year'] == 2000) & (data['Sex'] == 'M') & (data['Sport'] == 'Gymnastics')]
man2000 = data.loc[(data['Year'] == 2000) & (data['Sex'] == 'M')]
new2000.sort_values(by = 'Age')
# Out:
#             ID                        Name Sex   Age  Height  Weight  \
# 89397    45312            Paul Elbert Hamm   M  17.0   165.0    62.0
# 89384    45311            Morgan Carl Hamm   M  17.0   165.0    65.0
# 58621    29996  Dmitry Nikolayevich Drevin   M  18.0   170.0    59.0
# 263855  132038                  Xing Aowei   M  18.0   171.0    64.0
# 104052   52652          Damian Mark Istria   M  18.0   167.0    71.0
# ...        ...                         ...  ..   ...     ...     ...
# 131535   66202        Lzaro Lamelas Ramrez   M  26.0   163.0    59.0
# 92707    46975                  Craig Heap   M  27.0   167.0    65.0
# 104611   52946               Norimasa Iwai   M  27.0   157.0    55.0
# 142219   71348               Eric Lpez Ros   M  27.0   162.0    62.0
# 113511   57505          Dimitri Karbanenko   M  27.0   174.0    70.0
#
#                  Team  NOC        Games  Year  Season    City       Sport  \
# ...

# %%
man2000.shape
# Out:
# (4262, 15)

# %%
new2000.shape[0] / man2000.shape[0] * 100
# Out:
# 1.4781792585640545

# %% [markdown]
# **Answer: 1.5**

# %% [markdown]
# **3.What are the mean and standard deviation of height for female basketball players participated in the 2000 Olympics? Round the answer to the first decimal.**
#
# 178.5 and 7.2
# 179.4 and 10
# 180.7 and 6.7
# 182.4 and 9.1

# %%
w2000 = data.loc[(data['Year'] == 2000) & (data['Sex'] == 'F') & (data['Sport'] == 'Basketball')]
print(w2000['Height'].mean(), w2000['Height'].std())
# Out:
# 182.38732394366198 9.139462087892174

# %% [markdown]
# **Answer: 182.4 and 9.1**

# %% [markdown]
# **4. Find a sportsperson participated in the 2002 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?**
#
# Judo
# Bobsleigh
# Weightlifting
# Boxing

# %%
sp2002 = data.loc[(data['Year'] == 2002)]
sp2002.sort_values (by = 'Weight', ascending = False)
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 99154    50171                   Emmanuel Hostache   M  26.0   190.0   123.0
# 129595   65246                         Kevin Kuske   M  23.0   196.0   116.0
# 270556  135315                       Zsolt Zsombor   M  30.0   193.0   115.0
# 60488    30980                         Dalibor uri   M  26.0   196.0   113.0
# 128125   64528                        Pavel Kubina   M  24.0   196.0   113.0
# ...        ...                                 ...  ..   ...     ...     ...
# 233264  117005                    Yevgeny Sviridov   M  27.0   183.0     NaN
# 234583  117636                       David Szurman   M  20.0   187.0     NaN
# 253219  126805  Maria Margaretha Antje "Marja" Vis   F  25.0     NaN     NaN
# 268939  134557                         Zhang Weina   F  23.0   166.0     NaN
# 270190  135168                     Artyom Znachkov   M  23.0   182.0     NaN
#
# ...

# %% [markdown]
# **Answer: Bobsleigh**

# %% [markdown]
# **5.How many times did Pawe Abratkiewicz participate in the Olympics held in different years?**
#
# 0
# 1
# 2
# 3

# %%
data4 = data.copy()
data4.drop_duplicates(subset = ['Year', 'Name'], inplace = True, keep = 'first')
data4
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271110  135568    Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data4 = data4.loc[(data4['Name'] == 'Pawe Abratkiewicz')]
data4
# Out:
#        ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 997   562  Pawe Abratkiewicz   M  21.0   183.0    84.0  Poland  POL
# 999   562  Pawe Abratkiewicz   M  27.0   183.0    84.0  Poland  POL
# 1001  562  Pawe Abratkiewicz   M  31.0   183.0    84.0  Poland  POL
#
#             Games  Year  Season            City          Sport  \
# 997   1992 Winter  1992  Winter     Albertville  Speed Skating
# 999   1998 Winter  1998  Winter          Nagano  Speed Skating
# 1001  2002 Winter  2002  Winter  Salt Lake City  Speed Skating
#
#                                Event Medal
# 997   Speed Skating Men's 500 metres   NaN
# 999   Speed Skating Men's 500 metres   NaN
# 1001  Speed Skating Men's 500 metres   NaN

# %% [markdown]
# **Answer: 3**

# %% [markdown]
# **6.How many silver medals in tennis did Australia win at the 2000 Olympics?**
#
# 0
# 1
# 2
# 3

# %%
data6 = data.loc[(data['Year'] == 2000) & (data['Sport'] == 'Tennis') & (data['Medal'] == 'Silver') & (data['Team'] == 'Australia')]
data6
# Out:
#             ID                    Name Sex   Age  Height  Weight       Team  \
# 262820  131504  Todd Andrew Woodbridge   M  29.0   178.0    75.0  Australia
# 262831  131511  Mark Raymond Woodforde   M  34.0   183.0    80.0  Australia
#
#         NOC        Games  Year  Season    City   Sport                 Event  \
# 262820  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
# 262831  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
#
#          Medal
# 262820  Silver
# 262831  Silver

# %% [markdown]
# **Answer: 2**

# %% [markdown]
# **7. Is it true that Switzerland won fewer medals than Serbia at the 2016 Olympics? Do not consider NaN values in Medal column.**
#
# Yes
# No

# %%
data7 = data.loc[(data['Year'] == 2016) & ((data['Team'] == 'Switzerland') | (data['Team'] == 'Serbia')) & (data['Medal'].notna())]
data7
# Out:
#             ID              Name Sex   Age  Height  Weight         Team  NOC  \
# 4417      2517      Milan Aleksi   M  30.0   193.0    96.0       Serbia  SRB
# 12203     6632  Timea Bacsinszky   F  27.0   170.0    62.0  Switzerland  SUI
# 22125    11656     Stefan Birevi   M  26.0   210.0   104.0       Serbia  SRB
# 24291    12738  Bogdan Bogdanovi   M  23.0   197.0    99.0       Serbia  SRB
# 24293    12740  Tijana Bogdanovi   F  18.0   172.0    52.0       Serbia  SRB
# ...        ...               ...  ..   ...     ...     ...          ...  ...
# 241429  120935     Marko Tomievi   M  26.0   174.0    80.0       Serbia  SRB
# 242890  121635       Lucas Tramr   M  26.0   183.0    75.0  Switzerland  SUI
# 251194  125792  Stefana Veljkovi   F  26.0   190.0    76.0       Serbia  SRB
# 270111  135132     Bojana ivkovi   F  28.0   186.0    72.0       Serbia  SRB
# 270370  135245      Milenko Zori   M  27.0   179.0    73.0       Serbia  SRB
#
# ...

# %%
serbia = data.loc[(data['Year'] == 2016) & (data['Team'] == 'Serbia') & (data['Medal'].notna())]
serbia.shape[0]
# Out:
# 54

# %%
swit = data.loc[(data['Year'] == 2016) & (data['Team'] == 'Switzerland') & (data['Medal'].notna())]
swit.shape[0]
# Out:
# 11

# %% [markdown]
# **Answer: Yes**

# %% [markdown]
# **8. What age category did the fewest and the most participants of the 2014 Olympics belong to?**
#
# [45-55] and [25-35) correspondingly
# [45-55] and [15-25) correspondingly
# [35-45] and [25-35) correspondingly
# [45-55] and [35-45) correspondingly

# %%
data4445 = data.loc[(data['Year'] == 2014) & (data['Age'] > 44) & (data['Age'] < 56)]
data2534 = data.loc[(data['Year'] == 2014) & (data['Age'] > 24) & (data['Age'] < 35)]
data1524 = data.loc[(data['Year'] == 2014) & (data['Age'] > 14) & (data['Age'] < 25)]
data3545 = data.loc[(data['Year'] == 2014) & (data['Age'] > 34) & (data['Age'] < 46)]
data3544 = data.loc[(data['Year'] == 2014) & (data['Age'] > 34) & (data['Age'] > 45)]
data2534
data4445
# Out:
#             ID                                               Name Sex   Age  \
# 54852    28109                                  Gary di Silvestri   M  47.0
# 105458   53346                                          John Jahr   M  48.0
# 233597  117158                         Ann E. Swisshelm (-Silver)   F  45.0
# 254305  127321  Hubertus Rudolph von Frstenberg-von Hohenlohe-...   M  55.0
# 257640  129024                            Winston Alexander Watts   M  46.0
#
#         Height  Weight           Team  NOC        Games  Year  Season   City  \
# 54852    183.0    82.0       Dominica  DMA  2014 Winter  2014  Winter  Sochi
# 105458   184.0     NaN        Germany  GER  2014 Winter  2014  Winter  Sochi
# 233597   175.0    72.0  United States  USA  2014 Winter  2014  Winter  Sochi
# 254305   183.0    77.0         Mexico  MEX  2014 Winter  2014  Winter  Sochi
# 257640   182.0   107.0        Jamaica  JAM  2014 Winter  2014  Winter  Sochi
#
# ...

# %% [markdown]
# **Answer: the fewest 44-55, the most 25-35**

# %% [markdown]
# **9. Is it true that there were Summer Olympics held in Lake Placid? Is it true that there were Winter Olympics held in Sankt Moritz?**
#
# Yes, Yes
# Yes, No
# No, Yes
# No, No

# %%
data9 = data.loc[(data['Season'] == 'Summer') & (data['City'] == 'Lake Placid')]
data9
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
data10 = data.loc[(data['Season'] == 'Winter') & (data['City'] == 'Sankt Moritz')]
data10
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 935        529    Karl Gustaf Emanuel Abrahamsson   M  31.0     NaN     NaN
# 1187       665              Gilbert Achard-Picard   M  29.0     NaN     NaN
# 1439       802             Tadeusz Ralf Adamowski   M  26.0   177.0    70.0
# 1454       810  Bridget Shirley Adams (-Bengough)   F  19.0     NaN     NaN
# 2707      1508                     Enrico Airoldi   M  24.0     NaN     NaN
# ...        ...                                ...  ..   ...     ...     ...
# 270713  135383           Annelore Zckert (-Zrost)   F  22.0     NaN     NaN
# 270714  135383           Annelore Zckert (-Zrost)   F  22.0     NaN     NaN
# 270863  135463                    Hans Zurbriggen   M  27.0     NaN     NaN
# 270881  135466                  Robert Zurbriggen   M  30.0     NaN     NaN
# 270882  135466                  Robert Zurbriggen   M  30.0     NaN     NaN
#
# ...

# %% [markdown]
# **Answer: no,yes**

# %% [markdown]
# **10.What is the absolute difference between the number of unique sports at the 1995 Olympics and 2016 Olympics?**
#
# 16
# 24
# 26
# 34

# %%
data1995 = data.loc[(data['Year'] == 1995)]
data1995
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
data2016 = data.loc[(data['Year'] == 2016)].copy()
data2016.drop_duplicates(subset = 'Sport', inplace = True, keep = 'first')
data2016.shape
# Out:
# (34, 15)

# %% [markdown]
# **Answer: 34**
