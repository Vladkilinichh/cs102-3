# %%
# %reload_ext rpy2.ipython
# %config IPCompleter.greedy=True
# %config InlineBackend.figure_format = 'retina'
# Out:
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %%
# %%R
#
# library(readr)
# library(dplyr)
# Out:
# R[write to console]:
# Attaching package: ‘dplyr’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# 1. How old were the youngest male and female participants of the 1996 Olympics?
#
# 16 and 15
#
# 14 and 12
#
# 16 and 12
#
# 13 and 11

# %%
# %%R
# data_frame <- read.csv('athlete_events.csv')

# %%
# %%R
# min(data_frame[data_frame['Sex'] == 'M'& data_frame['Year'] == '1996', 'Age'], na.rm=T)
# Out:
# [1] 14

# %%
# %%R
# min(data_frame[data_frame['Sex'] == 'F'& data_frame['Year'] == '1996', 'Age'], na.rm=T)
# Out:
# [1] 12

# %% [markdown]
# Answer: 14 and 12
#
# 2. What was the percentage of male gymnasts among all the male participants of the 2000 Olympics? Round the answer to the first decimal.
#
# Hint: here and further if needed drop duplicated sportsmen to count only unique ones.
#
# 0.2
#
# 1.5
#
# 2.5
#
# 7.7

# %%
# %%R
# clear <- data_frame[!duplicated(data_frame$Name), ]
# male_gym <- clear[clear['Sport'] == 'Gymnastics'& clear['Year'] == '2000' & clear['Sex'] == 'M', ]
# all_male <- clear[clear['Sex'] == 'M'& clear['Year'] == '2000', ]
# print(nrow(male_gym)/nrow(all_male))
# Out:
# [1] 0.01462264

# %% [markdown]
# Answer: 1.5
#
# 3.What are the mean and standard deviation of height for female basketball players participated in the 2000 Olympics? Round the answer to the first decimal.
#
# 178.5 and 7.2 179.4 and 10 180.7 and 6.7 182.4 and 9.1

# %%
# %%R
# data <- clear
# data <- data[data['Year'] == 2000 & data['Sex'] == 'F' & data['Sport'] == 'Basketball', ]
# print(lapply(data['Height'], mean, na.rm=T))
# print(lapply(data['Height'], sd, na.rm=T))
# Out:
# $Height
# [1] 181.9032
#
# $Height
# [1] 9.23258

# %% [markdown]
# Answer: 182.4 and 9.1
#
# 4. Find a sportsperson participated in the 2002 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?
#
# Judo Bobsleigh Weightlifting Boxing

# %%
# %%R
# data <- clear
# data <- data[data['Year'] == 2002, c('Weight', 'Sport')]
# print(data[data['Weight']==lapply(data['Weight'], max, na.rm=T), 'Sport'] )
# Out:
#  [1] <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
#  [8] <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# [15] <NA>      <NA>      Bobsleigh <NA>      <NA>      <NA>      <NA>
# [22] <NA>      <NA>      <NA>      <NA>      <NA>      <NA>      <NA>
# [29] <NA>      <NA>
# 66 Levels: Aeronautics Alpine Skiing Alpinism Archery ... Wrestling

# %% [markdown]
# Answer: Bobsleigh
#
# 5.How many times did Pawe Abratkiewicz participate in the Olympics held in different years?
#
# 0 1 2 3

# %%
# %%R
# pawe <- data_frame[data_frame['Name'] == 'Pawe Abratkiewicz', ]
# print(nrow(pawe[!duplicated(pawe$Games), ]))
# Out:
# [1] 3

# %% [markdown]
# Answer: 3
#
# 6.How many silver medals in tennis did Australia win at the 2000 Olympics?
#
# 0 1 2 3

# %%
# %%R
# aus <- data_frame[data_frame['Team'] == 'Australia', ]
# print(aus[aus['Games'] == '2000 Summer' & aus['Sport'] == 'Tennis' & aus['Medal'] == 'Silver', ])
# Out:
#            ID                   Name  Sex Age Height Weight      Team  NOC
# NA         NA                   <NA> <NA>  NA     NA     NA      <NA> <NA>
# NA.1       NA                   <NA> <NA>  NA     NA     NA      <NA> <NA>
# NA.2       NA                   <NA> <NA>  NA     NA     NA      <NA> <NA>
# NA.3       NA                   <NA> <NA>  NA     NA     NA      <NA> <NA>
# NA.4       NA                   <NA> <NA>  NA     NA     NA      <NA> <NA>
# NA.5       NA                   <NA> <NA>  NA     NA     NA      <NA> <NA>
# NA.6       NA                   <NA> <NA>  NA     NA     NA      <NA> <NA>
# NA.7       NA                   <NA> <NA>  NA     NA     NA      <NA> <NA>
# NA.8       NA                   <NA> <NA>  NA     NA     NA      <NA> <NA>
# 262821 131504 Todd Andrew Woodbridge    M  29    178     75 Australia  AUS
# 262832 131511 Mark Raymond Woodforde    M  34    183     80 Australia  AUS
#              Games Year Season   City  Sport                Event  Medal
# ...

# %% [markdown]
# Answer: 2
#
# 7. Is it true that Switzerland won fewer medals than Serbia at the 2016 Olympics? Do not consider NaN values in Medal column.
#
# Yes No

# %%
# %%R
# serb <- data_frame[data_frame['Year'] == 2016 & data_frame['Team'] == 'Serbia' & !is.na(data_frame['Medal']), ]
# switz <- data_frame[data_frame['Year'] == 2016 & data_frame['Team'] == 'Switzerland' & !is.na(data_frame['Medal']), ]
# print(nrow(serb))
# print(nrow(switz))
# Out:
# [1] 54
# [1] 11

# %% [markdown]
# Answer: Yes
#
# 8. What age category did the fewest and the most participants of the 2014 Olympics belong to?
#
# [45-55] and [25-35) correspondingly [45-55] and [15-25) correspondingly [35-45] and [25-35) correspondingly [45-55] and [35-45) correspondingly

# %%
# %%R
# data4555 <-data_frame[data_frame['Year'] == 2014 & data_frame['Age'] > 44 & data_frame['Age'] < 56, ]
# data2535 <-data_frame[data_frame['Year'] == 2014 & data_frame['Age'] > 25 & data_frame['Age'] < 35, ]
# data1525 <-data_frame[data_frame['Year'] == 2014 & data_frame['Age'] > 15 & data_frame['Age'] < 25, ]
# data3545 <-data_frame[data_frame['Year'] == 2014 & data_frame['Age'] > 34 & data_frame['Age'] < 46, ]
# data3544 <-data_frame[data_frame['Year'] == 2014 & data_frame['Age'] > 36 & data_frame['Age'] < 45, ]
# print(nrow(data4555))
# print(nrow(data2535))
# print(nrow(data1525))
# print(nrow(data3545))
# print(nrow(data3544))
# Out:
# [1] 5
# [1] 2199
# [1] 2017
# [1] 266
# [1] 113

# %% [markdown]
# Answer: the fewest 44-55, the most 25-35
#
# 9. Is it true that there were Summer Olympics held in Lake Placid? Is it true that there were Winter Olympics held in Sankt Moritz?
#
# Yes, Yes Yes, No No, Yes No, No

# %%
# %%R
# lake <-data_frame[data_frame['Season'] == 'Summer' & data_frame['City'] == 'Lake Placid', ]
# print(lake)
# Out:
#  [1] ID     Name   Sex    Age    Height Weight Team   NOC    Games  Year
# [11] Season City   Sport  Event  Medal
# <0 rows> (or 0-length row.names)

# %%
# %%R
# lakew <-data_frame[data_frame['Season'] == 'Winter' & data_frame['City'] == 'Lake Placid', ]
# print(nrow(lakew))
# Out:
#            ID                                                       Name Sex
# 31         11                                         Jorma Ilmari Aalto   M
# 676       393                                                Gnther Abel   M
# 715       407                                          Ral Daniel Abella   M
# 716       407                                          Ral Daniel Abella   M
# 717       407                                          Ral Daniel Abella   M
# 924       523                                      Trond Sevg Abrahamsen   M
# 1327      746                                                Goro Adachi   M
# 1692      938                                           Cary Glen Adgate   M
# 1800      998                                        ke Ronnie Adolfsson   M
# 1801      998                                        ke Ronnie Adolfsson   M
# 1802      998                                        ke Ronnie Adolfsson   M
# ...

# %% [markdown]
# Answer: no,yes
#
# 10.What is the absolute difference between the number of unique sports at the 1995 Olympics and 2016 Olympics?
#
# 16 24 26 34

# %%
# %%R
# olymp1995 <- data_frame[!duplicated(data_frame$Sport), ]
# print(nrow(olymp1995[olymp1995['Year'] == '1995', ]))
